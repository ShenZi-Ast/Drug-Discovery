# %% [markdown]
# <a href="https://colab.research.google.com/github/ShenZi-Ast/Drug-Discovery/blob/main/Finding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Computer Aided Discovery
# In this project we build a machine learnig model by using ChEMBL data base
# **In part 1**
# 1.   We collect the raw data from ChEMBL and chose between potentioal targets (***Number of df***)
# 2.   Processing uniqe ChEMBL_ID,SMILES,Standard_value of each compund(finding drug potency) (***Number of df***)
# 3. Concating the databases (***Number of df***)

# %% [markdown]
# **Step1:** Installing and importing required libraries

# %%
pip install chembl_webresource_client

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# **Step 2:** Searching in ChEMBL database to find the best target for our selected compound, which in this case is ***"THE NAME OF THE COMPUND"***

# %%
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# **Step3:** Filtering activity data of the selected chemical compund based on standard_type="IC50" and save it to a DataFrame and csv file as Bio_activity.csv

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %%
df = pd.read_csv('Bio_activity.csv')
df
# Out:
#                                             action_type activity_comment  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 9087                                                NaN              NaN
# 9088                                                NaN              NaN
# 9089                                                NaN              NaN
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %%
df.dropna
df.shape
# Out:
# (9091, 46)

# %%
df.to_csv('Bio_activity.csv', index=False)

# %% [markdown]
# **Step4**:Creating the secend dataframe to
# drop null and duplicated values from standard_value and canonical_smiles

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-9-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# ...

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# **Step5:**Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 9086      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 9087      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 9088      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 9089      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 9090      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#      standard_value
# 0             750.0
# 1             100.0
# ...

# %% [markdown]
# **Step5:** Indicating each compund status as (Active,Intermediate,Inactive) by creating a bioactivity class and defining the threshold.

# %%
bioactivity_threshold = []
for i in df3.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %% [markdown]
# **Step6:**

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4 = df4.dropna()
df4.to_csv('First_Tabel.csv', index=False)
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6364      CHEMBL4077169                    CN1c2ccccc2C(N2CCOCC2)c2ccccc21
# 6365      CHEMBL4065259                    CN1c2ccccc2C(N2CCSCC2)c2ccccc21
# 6366      CHEMBL4075825                     CN1c2ccccc2C(n2cncn2)c2ccccc21
# 6367      CHEMBL4075624       CN1c2ccccc2C(n2cnc([N+](=O)[O-])n2)c2ccccc21
# 6368      CHEMBL4088659               CN1c2ccccc2C(n2nnc3ccccc32)c2ccccc21
#
#      standard_value         class
# ...

# %%
df_no_smiles = df4.drop(columns='canonical_smiles')
smiles = []

for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_no_smiles,smiles], axis=1)
df5 = df_clean_smiles.dropna()
df5
# Out:
#      molecule_chembl_id standard_value         class  \
# 0          CHEMBL133897          750.0        active
# 1          CHEMBL336398          100.0        active
# 2          CHEMBL131588        50000.0      inactive
# 3          CHEMBL130628          300.0        active
# 4          CHEMBL130478          800.0        active
# ...                 ...            ...           ...
# 6364      CHEMBL4077169        12300.0        active
# 6365      CHEMBL4065259        11800.0  intermediate
# 6366      CHEMBL4075825        18800.0      inactive
# 6367      CHEMBL4075624        16700.0      inactive
# 6368      CHEMBL4088659        12400.0      inactive
#
#                                        canonical_smiles
# 0                 CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1            O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2     CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# ...

# %% [markdown]
# **PART 2** Investigating Druglikness with rule of LIPINSKI
#
# Lipinski's Rule stated the following:
#
# 1.  Molecular weight < 500 Dalton
# 2.  Octanol-water partition coefficient (LogP) < 5
# 3. Hydrogen bond donors < 5
# 4. Hydrogen bond acceptors < 10

# %%
pip install rdkit

# %%
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
df_lipinski = lipinski(df5.canonical_smiles)
df_lipinski
# Out:
#            MW    LogP  NumHDonors  NumHAcceptors
# 0     312.325  2.8032         0.0            6.0
# 1     376.913  4.5546         0.0            5.0
# 2     426.851  5.3574         0.0            5.0
# 3     404.845  4.7069         0.0            5.0
# 4     346.334  3.0953         0.0            6.0
# ...       ...     ...         ...            ...
# 4158  280.371  3.1895         0.0            3.0
# 4159  296.439  3.9061         0.0            3.0
# 4160  262.316  2.9971         0.0            4.0
# 4161  307.313  2.9053         0.0            6.0
# 4162  312.376  4.1503         0.0            4.0
#
# [4163 rows x 4 columns]

# %%
df_combined = pd.concat([df5,df_lipinski], axis=1)
df6 = df_combined.dropna()
df6.to_csv('Second_Tabel.csv', index=False)
df6
# Out:
#      molecule_chembl_id standard_value     class  \
# 0          CHEMBL133897          750.0    active
# 1          CHEMBL336398          100.0    active
# 2          CHEMBL131588        50000.0  inactive
# 3          CHEMBL130628          300.0    active
# 4          CHEMBL130478          800.0    active
# ...                 ...            ...       ...
# 4153      CHEMBL2088785            9.4  inactive
# 4154      CHEMBL2088786           70.0  inactive
# 4156      CHEMBL2147460           5.18  inactive
# 4157      CHEMBL2147462           3.52  inactive
# 4158      CHEMBL2147461           4.04  inactive
#
#                                        canonical_smiles       MW     LogP  \
# 0                 CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1  312.325  2.80320
# 1            O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1  376.913  4.55460
# 2     CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1  426.851  5.35740
# 3         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F  404.845  4.70690
# ...
